# %% [markdown]
# # Web Scrapping

# %% [markdown]
# - Web scraping adalah proses ekstrasi data dari sebuah website.

# %% [markdown]
# # Case 1 Iphone - Erafone (Single Page)

# %% [markdown]
# ## Load Library

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %% [markdown]
# ## Specify the Main URL

# %%
url = 'https://eraspace.com/erafone/catalogsearch/result/?cat=40&p=1&q=iphone'

# %% [markdown]
# ## Connect to the URL

# %%
#Jika statusnya 200 maka udah OK
response = requests.get(url)
response
# Out:
# <Response [200]>

# %% [markdown]
# ## Parsing Main HTML

# %%
#Mengurai HTML
soup = BeautifulSoup(response.content, 'html.parser')

# %% [markdown]
# ## Find Specific Elements

# %%
#Outputnya itu jadi list
produk_hp = soup.find_all('li', 'item product product-item')
print(produk_hp)
# Out:
# [<li class="item product product-item"> <div class="product-item-info" data-container="product-grid">
# <!-- product badge -->
# <!--
# /**
#  * Copyright © 2019 PT Kemana Teknologi Solusi. All rights reserved.
#  * http://www.kemana.com
#  */
#
# /**
#  * @category Kemana
#  * @package  Kemana_Catalog
#  * @license  http://opensource.org/licenses/osl-3.0.php  Open Software License (OSL 3.0)
#  *
#  *
#  * @author   Imam Kusuma <ikusuma@kemana.com>
#  */
# -->
# <!-- product badge -->
# <a class="product photo product-item-photo" href="https://eraspace.com/erafone/apple-iphone-xs-64gb" tabindex="-1">
# <img alt="Apple iPhone Xs 64GB" class="photo image" height="150" src="https://eraspace.com/pub/media/catalog/product/cache/d03018dd3d9615b5c9bd12c6ee948951/i/p/iphone-xs-gold_1_1_1_3.jpg" width="150">
# </img></a>
# <div class="product details product-item-details">
# <strong class="product name product-item-name">
# <a class="product-item-link" href="https://eraspace.com/erafone/apple-iphone-xs-64gb">
#                                 Apple iPhone Xs 64GB                            </a>
# </strong>
# <div class="price-box price-final_price" data-price-box="product-id-946" data-product-id="946" data-role="priceBox">
# <span class="normal-price">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="19599000" data-price-type="finalPrice" id="product-price-946"><span class="price">Rp. 19.599.000</span></span>
# </span>
# </span>
# </div>
# <div class="product-item-inner">
# <div class="product actions product-item-actions">
# <div class="actions-primary">
# <form action="https://eraspace.com/checkout/cart/add/uenc/aHR0cHM6Ly9lcmFzcGFjZS5jb20vZXJhZm9uZS9jYXRhbG9nc2VhcmNoL3Jlc3VsdC8_Y2F0PTQwJnA9MSZxPWlwaG9uZQ%2C%2C/product/946/" data-product-sku="HAP-IPXS64-CON" data-role="tocart-form" method="post">
# <input name="product" type="hidden" value="946"/>
# <input name="uenc" type="hidden" value="aHR0cHM6Ly9lcmFzcGFjZS5jb20vY2hlY2tvdXQvY2FydC9hZGQvdWVuYy9hSFIwY0hNNkx5OWxjbUZ6Y0dGalpTNWpiMjB2WlhKaFptOXVaUzlqWVhSaGJHOW5jMlZoY21Ob0wzSmxjM1ZzZEM4X1kyRjBQVFF3Sm5BOU1TWnhQV2x3YUc5dVpRJTJDJTJDL3Byb2R1Y3QvOTQ2Lw,,"/>
# <input name="form_key" type="hidden" value="EC1ihyQcEx6jUzAY"> <input class="addtocart-button-wrapper" data-title="Masukkan Keranjang Belanja " type="hidden"/>
# <button class="action tocart primary" title="Masukkan Keranjang Belanja " type="submit">
# <span>Masukkan Keranjang Belanja </span>
# </button>
# </input></form>
# </div>
# <div class="actions-secondary" data-role="add-to-links">
# <a aria-label=" Favorit " class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/eraspace.com\/wishlist\/index\/add\/","data":{"product":"946","uenc":"aHR0cHM6Ly9lcmFzcGFjZS5jb20vZXJhZm9uZS9jYXRhbG9nc2VhcmNoL3Jlc3VsdC8_Y2F0PTQwJnA9MSZxPWlwaG9uZQ,,"}}' href="#" role="button" title="Favoritkan">
# <span>Favoritkan</span>
# </a>
# <a aria-label=" Bandingkan " class="action tocompare" data-post='{"action":"https:\/\/eraspace.com\/catalog\/product_compare\/add\/","data":{"product":"946","uenc":"aHR0cHM6Ly9lcmFzcGFjZS5jb20vZXJhZm9uZS9jYXRhbG9nc2VhcmNoL3Jlc3VsdC8_Y2F0PTQwJnA9MSZxPWlwaG9uZQ,,"}}' href="#" role="button" title=" Bandingkan ">
# <span> Bandingkan </span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>, <li class="item product product-item"> <div class="product-item-info" data-container="product-grid">
# <!-- product badge -->
# <!--
# /**
#  * Copyright © 2019 PT Kemana Teknologi Solusi. All rights reserved.
#  * http://www.kemana.com
#  */
#
# /**
#  * @category Kemana
#  * @package  Kemana_Catalog
#  * @license  http://opensource.org/licenses/osl-3.0.php  Open Software License (OSL 3.0)
#  *
#  *
#  * @author   Imam Kusuma <ikusuma@kemana.com>
#  */
# -->
# <!-- product badge -->
# <a class="product photo product-item-photo" href="https://eraspace.com/erafone/apple-iphone-x-256gb" tabindex="-1">
# <img alt="Apple iPhone X 256GB" class="photo image" height="150" src="https://eraspace.com/pub/media/catalog/product/cache/d03018dd3d9615b5c9bd12c6ee948951/i/p/iphone-x-silver_3_2_1_1_1.jpg" width="150">
# </img></a>
# <div class="product details product-item-details">
# <strong class="product name product-item-name">
# <a class="product-item-link" href="https://eraspace.com/erafone/apple-iphone-x-256gb">
#                                 Apple iPhone X 256GB                            </a>
# </strong>
# <div class="price-box price-final_price" data-price-box="product-id-939" data-product-id="939" data-role="priceBox">
# <span class="normal-price">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="19399000" data-price-type="finalPrice" id="product-price-939"><span class="price">Rp. 19.399.000</span></span>
# </span>
# </span>
# </div>
# <div class="product-item-inner">
# <div class="product actions product-item-actions">
# <div class="actions-primary">
# <form action="https://eraspace.com/checkout/cart/add/uenc/aHR0cHM6Ly9lcmFzcGFjZS5jb20vZXJhZm9uZS9jYXRhbG9nc2VhcmNoL3Jlc3VsdC8_Y2F0PTQwJnA9MSZxPWlwaG9uZQ%2C%2C/product/939/" data-product-sku="HAP-IPX-256-CON" data-role="tocart-form" method="post">
# <input name="product" type="hidden" value="939"/>
# <input name="uenc" type="hidden" value="aHR0cHM6Ly9lcmFzcGFjZS5jb20vY2hlY2tvdXQvY2FydC9hZGQvdWVuYy9hSFIwY0hNNkx5OWxjbUZ6Y0dGalpTNWpiMjB2WlhKaFptOXVaUzlqWVhSaGJHOW5jMlZoY21Ob0wzSmxjM1ZzZEM4X1kyRjBQVFF3Sm5BOU1TWnhQV2x3YUc5dVpRJTJDJTJDL3Byb2R1Y3QvOTM5Lw,,"/>
# <input name="form_key" type="hidden" value="EC1ihyQcEx6jUzAY"> <input class="addtocart-button-wrapper" data-title="Masukkan Keranjang Belanja " type="hidden"/>
# <button class="action tocart primary" title="Masukkan Keranjang Belanja " type="submit">
# <span>Masukkan Keranjang Belanja </span>
# </button>
# </input></form>
# </div>
# <div class="actions-secondary" data-role="add-to-links">
# <a aria-label=" Favorit " class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/eraspace.com\/wishlist\/index\/add\/","data":{"product":"939","uenc":"aHR0cHM6Ly9lcmFzcGFjZS5jb20vZXJhZm9uZS9jYXRhbG9nc2VhcmNoL3Jlc3VsdC8_Y2F0PTQwJnA9MSZxPWlwaG9uZQ,,"}}' href="#" role="button" title="Favoritkan">
# <span>Favoritkan</span>
# </a>
# <a aria-label=" Bandingkan " class="action tocompare" data-post='{"action":"https:\/\/eraspace.com\/catalog\/product_compare\/add\/","data":{"product":"939","uenc":"aHR0cHM6Ly9lcmFzcGFjZS5jb20vZXJhZm9uZS9jYXRhbG9nc2VhcmNoL3Jlc3VsdC8_Y2F0PTQwJnA9MSZxPWlwaG9uZQ,,"}}' href="#" role="button" title=" Bandingkan ">
# <span> Bandingkan </span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>, <li class="item product product-item"> <div class="product-item-info" data-container="product-grid">
# <!-- product badge -->
# <!--
# /**
#  * Copyright © 2019 PT Kemana Teknologi Solusi. All rights reserved.
#  * http://www.kemana.com
#  */
#
# /**
#  * @category Kemana
#  * @package  Kemana_Catalog
#  * @license  http://opensource.org/licenses/osl-3.0.php  Open Software License (OSL 3.0)
#  *
#  *
#  * @author   Imam Kusuma <ikusuma@kemana.com>
#  */
# -->
# <!-- product badge -->
# <a class="product photo product-item-photo" href="https://eraspace.com/erafone/apple-iphone-xs-512gb" tabindex="-1">
# <img alt="Apple iPhone Xs 512GB" class="photo image" height="150" src="https://eraspace.com/pub/media/catalog/product/cache/d03018dd3d9615b5c9bd12c6ee948951/i/p/iphone-xs-space-gray_1_1_1_2.jpg" width="150">
# </img></a>
# <div class="product details product-item-details">
# <strong class="product name product-item-name">
# <a class="product-item-link" href="https://eraspace.com/erafone/apple-iphone-xs-512gb">
#                                 Apple iPhone Xs 512GB                            </a>
# </strong>
# <div class="price-box price-final_price" data-price-box="product-id-945" data-product-id="945" data-role="priceBox">
# <span class="normal-price">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="26599000" data-price-type="finalPrice" id="product-price-945"><span class="price">Rp. 26.599.000</span></span>
# </span>
# </span>
# </div>
# <div class="product-item-inner">
# <div class="product actions product-item-actions">
# <div class="actions-primary">
# <form action="https://eraspace.com/checkout/cart/add/uenc/aHR0cHM6Ly9lcmFzcGFjZS5jb20vZXJhZm9uZS9jYXRhbG9nc2VhcmNoL3Jlc3VsdC8_Y2F0PTQwJnA9MSZxPWlwaG9uZQ%2C%2C/product/945/" data-product-sku="HAP-IPXS512-CON" data-role="tocart-form" method="post">
# <input name="product" type="hidden" value="945"/>
# <input name="uenc" type="hidden" value="aHR0cHM6Ly9lcmFzcGFjZS5jb20vY2hlY2tvdXQvY2FydC9hZGQvdWVuYy9hSFIwY0hNNkx5OWxjbUZ6Y0dGalpTNWpiMjB2WlhKaFptOXVaUzlqWVhSaGJHOW5jMlZoY21Ob0wzSmxjM1ZzZEM4X1kyRjBQVFF3Sm5BOU1TWnhQV2x3YUc5dVpRJTJDJTJDL3Byb2R1Y3QvOTQ1Lw,,"/>
# <input name="form_key" type="hidden" value="EC1ihyQcEx6jUzAY"> <input class="addtocart-button-wrapper" data-title="Masukkan Keranjang Belanja " type="hidden"/>
# <button class="action tocart primary" title="Masukkan Keranjang Belanja " type="submit">
# <span>Masukkan Keranjang Belanja </span>
# </button>
# </input></form>
# </div>
# <div class="actions-secondary" data-role="add-to-links">
# <a aria-label=" Favorit " class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/eraspace.com\/wishlist\/index\/add\/","data":{"product":"945","uenc":"aHR0cHM6Ly9lcmFzcGFjZS5jb20vZXJhZm9uZS9jYXRhbG9nc2VhcmNoL3Jlc3VsdC8_Y2F0PTQwJnA9MSZxPWlwaG9uZQ,,"}}' href="#" role="button" title="Favoritkan">
# <span>Favoritkan</span>
# </a>
# <a aria-label=" Bandingkan " class="action tocompare" data-post='{"action":"https:\/\/eraspace.com\/catalog\/product_compare\/add\/","data":{"product":"945","uenc":"aHR0cHM6Ly9lcmFzcGFjZS5jb20vZXJhZm9uZS9jYXRhbG9nc2VhcmNoL3Jlc3VsdC8_Y2F0PTQwJnA9MSZxPWlwaG9uZQ,,"}}' href="#" role="button" title=" Bandingkan ">
# <span> Bandingkan </span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>, <li class="item product product-item"> <div class="product-item-info" data-container="product-grid">
# <!-- product badge -->
# <!--
# /**
#  * Copyright © 2019 PT Kemana Teknologi Solusi. All rights reserved.
#  * http://www.kemana.com
#  */
#
# /**
#  * @category Kemana
#  * @package  Kemana_Catalog
#  * @license  http://opensource.org/licenses/osl-3.0.php  Open Software License (OSL 3.0)
#  *
#  *
#  * @author   Imam Kusuma <ikusuma@kemana.com>
#  */
# -->
# <!-- product badge -->
# <a class="product photo product-item-photo" href="https://eraspace.com/erafone/apple-iphone-xr-64gb" tabindex="-1">
# <img alt="Apple iPhone Xr 64GB" class="photo image" height="150" src="https://eraspace.com/pub/media/catalog/product/cache/d03018dd3d9615b5c9bd12c6ee948951/i/p/iphone-xr-white_1_1_1_3.jpg" width="150">
# </img></a>
# <div class="product details product-item-details">
# <strong class="product name product-item-name">
# <a class="product-item-link" href="https://eraspace.com/erafone/apple-iphone-xr-64gb">
#                                 Apple iPhone Xr 64GB                            </a>
# </strong>
# <div class="price-box price-final_price" data-price-box="product-id-943" data-product-id="943" data-role="priceBox">
# <span class="normal-price">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="12999000" data-price-type="finalPrice" id="product-price-943"><span class="price">Rp. 12.999.000</span></span>
# </span>
# </span>
# </div>
# <div class="product-item-inner">
# <div class="product actions product-item-actions">
# <div class="actions-primary">
# <form action="https://eraspace.com/checkout/cart/add/uenc/aHR0cHM6Ly9lcmFzcGFjZS5jb20vZXJhZm9uZS9jYXRhbG9nc2VhcmNoL3Jlc3VsdC8_Y2F0PTQwJnA9MSZxPWlwaG9uZQ%2C%2C/product/943/" data-product-sku="HAP-IPXR64-CON" data-role="tocart-form" method="post">
# <input name="product" type="hidden" value="943"/>
# <input name="uenc" type="hidden" value="aHR0cHM6Ly9lcmFzcGFjZS5jb20vY2hlY2tvdXQvY2FydC9hZGQvdWVuYy9hSFIwY0hNNkx5OWxjbUZ6Y0dGalpTNWpiMjB2WlhKaFptOXVaUzlqWVhSaGJHOW5jMlZoY21Ob0wzSmxjM1ZzZEM4X1kyRjBQVFF3Sm5BOU1TWnhQV2x3YUc5dVpRJTJDJTJDL3Byb2R1Y3QvOTQzLw,,"/>
# <input name="form_key" type="hidden" value="EC1ihyQcEx6jUzAY"> <input class="addtocart-button-wrapper" data-title="Masukkan Keranjang Belanja " type="hidden"/>
# <button class="action tocart primary" title="Masukkan Keranjang Belanja " type="submit">
# <span>Masukkan Keranjang Belanja </span>
# </button>
# </input></form>
# </div>
# <div class="actions-secondary" data-role="add-to-links">
# <a aria-label=" Favorit " class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/eraspace.com\/wishlist\/index\/add\/","data":{"product":"943","uenc":"aHR0cHM6Ly9lcmFzcGFjZS5jb20vZXJhZm9uZS9jYXRhbG9nc2VhcmNoL3Jlc3VsdC8_Y2F0PTQwJnA9MSZxPWlwaG9uZQ,,"}}' href="#" role="button" title="Favoritkan">
# <span>Favoritkan</span>
# </a>
# <a aria-label=" Bandingkan " class="action tocompare" data-post='{"action":"https:\/\/eraspace.com\/catalog\/product_compare\/add\/","data":{"product":"943","uenc":"aHR0cHM6Ly9lcmFzcGFjZS5jb20vZXJhZm9uZS9jYXRhbG9nc2VhcmNoL3Jlc3VsdC8_Y2F0PTQwJnA9MSZxPWlwaG9uZQ,,"}}' href="#" role="button" title=" Bandingkan ">
# <span> Bandingkan </span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>, <li class="item product product-item"> <div class="product-item-info" data-container="product-grid">
# <!-- product badge -->
# <!--
# /**
#  * Copyright © 2019 PT Kemana Teknologi Solusi. All rights reserved.
#  * http://www.kemana.com
#  */
#
# /**
#  * @category Kemana
#  * @package  Kemana_Catalog
#  * @license  http://opensource.org/licenses/osl-3.0.php  Open Software License (OSL 3.0)
#  *
#  *
#  * @author   Imam Kusuma <ikusuma@kemana.com>
#  */
# -->
# <!-- product badge -->
# <a class="product photo product-item-photo" href="https://eraspace.com/erafone/apple-iphone-xs-max-256gb" tabindex="-1">
# <img alt="Apple iPhone Xs Max 256GB" class="photo image" height="150" src="https://eraspace.com/pub/media/catalog/product/cache/d03018dd3d9615b5c9bd12c6ee948951/i/p/iphone-xs-max-gold_1_1_1.jpg" width="150">
# </img></a>
# <div class="product details product-item-details">
# <strong class="product name product-item-name">
# <a class="product-item-link" href="https://eraspace.com/erafone/apple-iphone-xs-max-256gb">
#                                 Apple iPhone Xs Max 256GB                            </a>
# </strong>
# <div class="price-box price-final_price" data-price-box="product-id-947" data-product-id="947" data-role="priceBox">
# <span class="normal-price">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="22999000" data-price-type="finalPrice" id="product-price-947"><span class="price">Rp. 22.999.000</span></span>
# </span>
# </span>
# </div>
# <div class="product-item-inner">
# <div class="product actions product-item-actions">
# <div class="actions-primary">
# <form action="https://eraspace.com/checkout/cart/add/uenc/aHR0cHM6Ly9lcmFzcGFjZS5jb20vZXJhZm9uZS9jYXRhbG9nc2VhcmNoL3Jlc3VsdC8_Y2F0PTQwJnA9MSZxPWlwaG9uZQ%2C%2C/product/947/" data-product-sku="HAP-IPXSM256-CON" data-role="tocart-form" method="post">
# <input name="product" type="hidden" value="947"/>
# <input name="uenc" type="hidden" value="aHR0cHM6Ly9lcmFzcGFjZS5jb20vY2hlY2tvdXQvY2FydC9hZGQvdWVuYy9hSFIwY0hNNkx5OWxjbUZ6Y0dGalpTNWpiMjB2WlhKaFptOXVaUzlqWVhSaGJHOW5jMlZoY21Ob0wzSmxjM1ZzZEM4X1kyRjBQVFF3Sm5BOU1TWnhQV2x3YUc5dVpRJTJDJTJDL3Byb2R1Y3QvOTQ3Lw,,"/>
# <input name="form_key" type="hidden" value="EC1ihyQcEx6jUzAY"> <input class="addtocart-button-wrapper" data-title="Masukkan Keranjang Belanja " type="hidden"/>
# <button class="action tocart primary" title="Masukkan Keranjang Belanja " type="submit">
# <span>Masukkan Keranjang Belanja </span>
# </button>
# </input></form>
# </div>
# <div class="actions-secondary" data-role="add-to-links">
# <a aria-label=" Favorit " class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/eraspace.com\/wishlist\/index\/add\/","data":{"product":"947","uenc":"aHR0cHM6Ly9lcmFzcGFjZS5jb20vZXJhZm9uZS9jYXRhbG9nc2VhcmNoL3Jlc3VsdC8_Y2F0PTQwJnA9MSZxPWlwaG9uZQ,,"}}' href="#" role="button" title="Favoritkan">
# <span>Favoritkan</span>
# </a>
# <a aria-label=" Bandingkan " class="action tocompare" data-post='{"action":"https:\/\/eraspace.com\/catalog\/product_compare\/add\/","data":{"product":"947","uenc":"aHR0cHM6Ly9lcmFzcGFjZS5jb20vZXJhZm9uZS9jYXRhbG9nc2VhcmNoL3Jlc3VsdC8_Y2F0PTQwJnA9MSZxPWlwaG9uZQ,,"}}' href="#" role="button" title=" Bandingkan ">
# <span> Bandingkan </span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>, <li class="item product product-item"> <div class="product-item-info" data-container="product-grid">
# <!-- product badge -->
# <!--
# /**
#  * Copyright © 2019 PT Kemana Teknologi Solusi. All rights reserved.
#  * http://www.kemana.com
#  */
#
# /**
#  * @category Kemana
#  * @package  Kemana_Catalog
#  * @license  http://opensource.org/licenses/osl-3.0.php  Open Software License (OSL 3.0)
#  *
#  *
#  * @author   Imam Kusuma <ikusuma@kemana.com>
#  */
# -->
# <!-- product badge -->
# <a class="product photo product-item-photo" href="https://eraspace.com/erafone/apple-iphone-xs-256gb" tabindex="-1">
# <img alt="Apple iPhone Xs 256GB" class="photo image" height="150" src="https://eraspace.com/pub/media/catalog/product/cache/d03018dd3d9615b5c9bd12c6ee948951/i/p/iphone-xs-silver_1_1_2_1.jpg" width="150">
# </img></a>
# <div class="product details product-item-details">
# <strong class="product name product-item-name">
# <a class="product-item-link" href="https://eraspace.com/erafone/apple-iphone-xs-256gb">
#                                 Apple iPhone Xs 256GB                            </a>
# </strong>
# <div class="price-box price-final_price" data-price-box="product-id-944" data-product-id="944" data-role="priceBox">
# <span class="normal-price">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="22599000" data-price-type="finalPrice" id="product-price-944"><span class="price">Rp. 22.599.000</span></span>
# </span>
# </span>
# </div>
# <div class="product-item-inner">
# <div class="product actions product-item-actions">
# <div class="actions-primary">
# <form action="https://eraspace.com/checkout/cart/add/uenc/aHR0cHM6Ly9lcmFzcGFjZS5jb20vZXJhZm9uZS9jYXRhbG9nc2VhcmNoL3Jlc3VsdC8_Y2F0PTQwJnA9MSZxPWlwaG9uZQ%2C%2C/product/944/" data-product-sku="HAP-IPXS256-CON" data-role="tocart-form" method="post">
# <input name="product" type="hidden" value="944"/>
# <input name="uenc" type="hidden" value="aHR0cHM6Ly9lcmFzcGFjZS5jb20vY2hlY2tvdXQvY2FydC9hZGQvdWVuYy9hSFIwY0hNNkx5OWxjbUZ6Y0dGalpTNWpiMjB2WlhKaFptOXVaUzlqWVhSaGJHOW5jMlZoY21Ob0wzSmxjM1ZzZEM4X1kyRjBQVFF3Sm5BOU1TWnhQV2x3YUc5dVpRJTJDJTJDL3Byb2R1Y3QvOTQ0Lw,,"/>
# <input name="form_key" type="hidden" value="EC1ihyQcEx6jUzAY"> <input class="addtocart-button-wrapper" data-title="Masukkan Keranjang Belanja " type="hidden"/>
# <button class="action tocart primary" title="Masukkan Keranjang Belanja " type="submit">
# <span>Masukkan Keranjang Belanja </span>
# </button>
# </input></form>
# </div>
# <div class="actions-secondary" data-role="add-to-links">
# <a aria-label=" Favorit " class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/eraspace.com\/wishlist\/index\/add\/","data":{"product":"944","uenc":"aHR0cHM6Ly9lcmFzcGFjZS5jb20vZXJhZm9uZS9jYXRhbG9nc2VhcmNoL3Jlc3VsdC8_Y2F0PTQwJnA9MSZxPWlwaG9uZQ,,"}}' href="#" role="button" title="Favoritkan">
# <span>Favoritkan</span>
# </a>
# <a aria-label=" Bandingkan " class="action tocompare" data-post='{"action":"https:\/\/eraspace.com\/catalog\/product_compare\/add\/","data":{"product":"944","uenc":"aHR0cHM6Ly9lcmFzcGFjZS5jb20vZXJhZm9uZS9jYXRhbG9nc2VhcmNoL3Jlc3VsdC8_Y2F0PTQwJnA9MSZxPWlwaG9uZQ,,"}}' href="#" role="button" title=" Bandingkan ">
# <span> Bandingkan </span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>, <li class="item product product-item"> <div class="product-item-info" data-container="product-grid">
# <!-- product badge -->
# <!--
# /**
#  * Copyright © 2019 PT Kemana Teknologi Solusi. All rights reserved.
#  * http://www.kemana.com
#  */
#
# /**
#  * @category Kemana
#  * @package  Kemana_Catalog
#  * @license  http://opensource.org/licenses/osl-3.0.php  Open Software License (OSL 3.0)
#  *
#  *
#  * @author   Imam Kusuma <ikusuma@kemana.com>
#  */
# -->
# <!-- product badge -->
# <a class="product photo product-item-photo" href="https://eraspace.com/erafone/apple-iphone-xr-256gb" tabindex="-1">
# <img alt="Apple iPhone Xr 256GB" class="photo image" height="150" src="https://eraspace.com/pub/media/catalog/product/cache/d03018dd3d9615b5c9bd12c6ee948951/i/p/iphone-xr-black_1_1_1_2.jpg" width="150">
# </img></a>
# <div class="product details product-item-details">
# <strong class="product name product-item-name">
# <a class="product-item-link" href="https://eraspace.com/erafone/apple-iphone-xr-256gb">
#                                 Apple iPhone Xr 256GB                            </a>
# </strong>
# <div class="price-box price-final_price" data-price-box="product-id-942" data-product-id="942" data-role="priceBox">
# <span class="normal-price">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="15999000" data-price-type="finalPrice" id="product-price-942"><span class="price">Rp. 15.999.000</span></span>
# </span>
# </span>
# </div>
# <div class="product-item-inner">
# <div class="product actions product-item-actions">
# <div class="actions-primary">
# <form action="https://eraspace.com/checkout/cart/add/uenc/aHR0cHM6Ly9lcmFzcGFjZS5jb20vZXJhZm9uZS9jYXRhbG9nc2VhcmNoL3Jlc3VsdC8_Y2F0PTQwJnA9MSZxPWlwaG9uZQ%2C%2C/product/942/" data-product-sku="HAP-IPXR256-CON" data-role="tocart-form" method="post">
# <input name="product" type="hidden" value="942"/>
# <input name="uenc" type="hidden" value="aHR0cHM6Ly9lcmFzcGFjZS5jb20vY2hlY2tvdXQvY2FydC9hZGQvdWVuYy9hSFIwY0hNNkx5OWxjbUZ6Y0dGalpTNWpiMjB2WlhKaFptOXVaUzlqWVhSaGJHOW5jMlZoY21Ob0wzSmxjM1ZzZEM4X1kyRjBQVFF3Sm5BOU1TWnhQV2x3YUc5dVpRJTJDJTJDL3Byb2R1Y3QvOTQyLw,,"/>
# <input name="form_key" type="hidden" value="EC1ihyQcEx6jUzAY"> <input class="addtocart-button-wrapper" data-title="Masukkan Keranjang Belanja " type="hidden"/>
# <button class="action tocart primary" title="Masukkan Keranjang Belanja " type="submit">
# <span>Masukkan Keranjang Belanja </span>
# </button>
# </input></form>
# </div>
# <div class="actions-secondary" data-role="add-to-links">
# <a aria-label=" Favorit " class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/eraspace.com\/wishlist\/index\/add\/","data":{"product":"942","uenc":"aHR0cHM6Ly9lcmFzcGFjZS5jb20vZXJhZm9uZS9jYXRhbG9nc2VhcmNoL3Jlc3VsdC8_Y2F0PTQwJnA9MSZxPWlwaG9uZQ,,"}}' href="#" role="button" title="Favoritkan">
# <span>Favoritkan</span>
# </a>
# <a aria-label=" Bandingkan " class="action tocompare" data-post='{"action":"https:\/\/eraspace.com\/catalog\/product_compare\/add\/","data":{"product":"942","uenc":"aHR0cHM6Ly9lcmFzcGFjZS5jb20vZXJhZm9uZS9jYXRhbG9nc2VhcmNoL3Jlc3VsdC8_Y2F0PTQwJnA9MSZxPWlwaG9uZQ,,"}}' href="#" role="button" title=" Bandingkan ">
# <span> Bandingkan </span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>, <li class="item product product-item"> <div class="product-item-info" data-container="product-grid">
# <!-- product badge -->
# <!--
# /**
#  * Copyright © 2019 PT Kemana Teknologi Solusi. All rights reserved.
#  * http://www.kemana.com
#  */
#
# /**
#  * @category Kemana
#  * @package  Kemana_Catalog
#  * @license  http://opensource.org/licenses/osl-3.0.php  Open Software License (OSL 3.0)
#  *
#  *
#  * @author   Imam Kusuma <ikusuma@kemana.com>
#  */
# -->
# <!-- product badge -->
# <a class="product photo product-item-photo" href="https://eraspace.com/erafone/apple-iphone-xs-max-512gb" tabindex="-1">
# <img alt="Apple iPhone Xs Max 512GB" class="photo image" height="150" src="https://eraspace.com/pub/media/catalog/product/cache/d03018dd3d9615b5c9bd12c6ee948951/i/p/iphone-xs-max-silver_1_1_1_1.jpg" width="150">
# </img></a>
# <div class="product details product-item-details">
# <strong class="product name product-item-name">
# <a class="product-item-link" href="https://eraspace.com/erafone/apple-iphone-xs-max-512gb">
#                                 Apple iPhone Xs Max 512GB                            </a>
# </strong>
# <div class="price-box price-final_price" data-price-box="product-id-948" data-product-id="948" data-role="priceBox">
# <span class="normal-price">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="26999000" data-price-type="finalPrice" id="product-price-948"><span class="price">Rp. 26.999.000</span></span>
# </span>
# </span>
# </div>
# <div class="product-item-inner">
# <div class="product actions product-item-actions">
# <div class="actions-primary">
# <form action="https://eraspace.com/checkout/cart/add/uenc/aHR0cHM6Ly9lcmFzcGFjZS5jb20vZXJhZm9uZS9jYXRhbG9nc2VhcmNoL3Jlc3VsdC8_Y2F0PTQwJnA9MSZxPWlwaG9uZQ%2C%2C/product/948/" data-product-sku="HAP-IPXSM512-CON" data-role="tocart-form" method="post">
# <input name="product" type="hidden" value="948"/>
# <input name="uenc" type="hidden" value="aHR0cHM6Ly9lcmFzcGFjZS5jb20vY2hlY2tvdXQvY2FydC9hZGQvdWVuYy9hSFIwY0hNNkx5OWxjbUZ6Y0dGalpTNWpiMjB2WlhKaFptOXVaUzlqWVhSaGJHOW5jMlZoY21Ob0wzSmxjM1ZzZEM4X1kyRjBQVFF3Sm5BOU1TWnhQV2x3YUc5dVpRJTJDJTJDL3Byb2R1Y3QvOTQ4Lw,,"/>
# <input name="form_key" type="hidden" value="EC1ihyQcEx6jUzAY"> <input class="addtocart-button-wrapper" data-title="Masukkan Keranjang Belanja " type="hidden"/>
# <button class="action tocart primary" title="Masukkan Keranjang Belanja " type="submit">
# <span>Masukkan Keranjang Belanja </span>
# </button>
# </input></form>
# </div>
# <div class="actions-secondary" data-role="add-to-links">
# <a aria-label=" Favorit " class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/eraspace.com\/wishlist\/index\/add\/","data":{"product":"948","uenc":"aHR0cHM6Ly9lcmFzcGFjZS5jb20vZXJhZm9uZS9jYXRhbG9nc2VhcmNoL3Jlc3VsdC8_Y2F0PTQwJnA9MSZxPWlwaG9uZQ,,"}}' href="#" role="button" title="Favoritkan">
# <span>Favoritkan</span>
# </a>
# <a aria-label=" Bandingkan " class="action tocompare" data-post='{"action":"https:\/\/eraspace.com\/catalog\/product_compare\/add\/","data":{"product":"948","uenc":"aHR0cHM6Ly9lcmFzcGFjZS5jb20vZXJhZm9uZS9jYXRhbG9nc2VhcmNoL3Jlc3VsdC8_Y2F0PTQwJnA9MSZxPWlwaG9uZQ,,"}}' href="#" role="button" title=" Bandingkan ">
# <span> Bandingkan </span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>, <li class="item product product-item"> <div class="product-item-info" data-container="product-grid">
# <!-- product badge -->
# <!--
# /**
#  * Copyright © 2019 PT Kemana Teknologi Solusi. All rights reserved.
#  * http://www.kemana.com
#  */
#
# /**
#  * @category Kemana
#  * @package  Kemana_Catalog
#  * @license  http://opensource.org/licenses/osl-3.0.php  Open Software License (OSL 3.0)
#  *
#  *
#  * @author   Imam Kusuma <ikusuma@kemana.com>
#  */
# -->
# <!-- product badge -->
# <a class="product photo product-item-photo" href="https://eraspace.com/erafone/apple-iphone-8-plus-256gb" tabindex="-1">
# <img alt="Apple iPhone 8 Plus 256GB" class="photo image" height="150" src="https://eraspace.com/pub/media/catalog/product/cache/d03018dd3d9615b5c9bd12c6ee948951/i/p/iphone-8-plus-gold_4_1_1_1_1.jpg" width="150">
# </img></a>
# <div class="product details product-item-details">
# <strong class="product name product-item-name">
# <a class="product-item-link" href="https://eraspace.com/erafone/apple-iphone-8-plus-256gb">
#                                 Apple iPhone 8 Plus 256GB                            </a>
# </strong>
# <div class="price-box price-final_price" data-price-box="product-id-938" data-product-id="938" data-role="priceBox">
# <span class="normal-price">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="15499000" data-price-type="finalPrice" id="product-price-938"><span class="price">Rp. 15.499.000</span></span>
# </span>
# </span>
# </div>
# <div class="product-item-inner">
# <div class="product actions product-item-actions">
# <div class="actions-primary">
# <form action="https://eraspace.com/checkout/cart/add/uenc/aHR0cHM6Ly9lcmFzcGFjZS5jb20vZXJhZm9uZS9jYXRhbG9nc2VhcmNoL3Jlc3VsdC8_Y2F0PTQwJnA9MSZxPWlwaG9uZQ%2C%2C/product/938/" data-product-sku="HAP-IP8P-256-CON" data-role="tocart-form" method="post">
# <input name="product" type="hidden" value="938"/>
# <input name="uenc" type="hidden" value="aHR0cHM6Ly9lcmFzcGFjZS5jb20vY2hlY2tvdXQvY2FydC9hZGQvdWVuYy9hSFIwY0hNNkx5OWxjbUZ6Y0dGalpTNWpiMjB2WlhKaFptOXVaUzlqWVhSaGJHOW5jMlZoY21Ob0wzSmxjM1ZzZEM4X1kyRjBQVFF3Sm5BOU1TWnhQV2x3YUc5dVpRJTJDJTJDL3Byb2R1Y3QvOTM4Lw,,"/>
# <input name="form_key" type="hidden" value="EC1ihyQcEx6jUzAY"> <input class="addtocart-button-wrapper" data-title="Masukkan Keranjang Belanja " type="hidden"/>
# <button class="action tocart primary" title="Masukkan Keranjang Belanja " type="submit">
# <span>Masukkan Keranjang Belanja </span>
# </button>
# </input></form>
# </div>
# <div class="actions-secondary" data-role="add-to-links">
# <a aria-label=" Favorit " class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/eraspace.com\/wishlist\/index\/add\/","data":{"product":"938","uenc":"aHR0cHM6Ly9lcmFzcGFjZS5jb20vZXJhZm9uZS9jYXRhbG9nc2VhcmNoL3Jlc3VsdC8_Y2F0PTQwJnA9MSZxPWlwaG9uZQ,,"}}' href="#" role="button" title="Favoritkan">
# <span>Favoritkan</span>
# </a>
# <a aria-label=" Bandingkan " class="action tocompare" data-post='{"action":"https:\/\/eraspace.com\/catalog\/product_compare\/add\/","data":{"product":"938","uenc":"aHR0cHM6Ly9lcmFzcGFjZS5jb20vZXJhZm9uZS9jYXRhbG9nc2VhcmNoL3Jlc3VsdC8_Y2F0PTQwJnA9MSZxPWlwaG9uZQ,,"}}' href="#" role="button" title=" Bandingkan ">
# <span> Bandingkan </span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>, <li class="item product product-item"> <div class="product-item-info" data-container="product-grid">
# <!-- product badge -->
# <!--
# /**
#  * Copyright © 2019 PT Kemana Teknologi Solusi. All rights reserved.
#  * http://www.kemana.com
#  */
#
# /**
#  * @category Kemana
#  * @package  Kemana_Catalog
#  * @license  http://opensource.org/licenses/osl-3.0.php  Open Software License (OSL 3.0)
#  *
#  *
#  * @author   Imam Kusuma <ikusuma@kemana.com>
#  */
# -->
# <!-- product badge -->
# <a class="product photo product-item-photo" href="https://eraspace.com/erafone/apple-iphone-8-256gb" tabindex="-1">
# <img alt="Apple iPhone 8 256GB" class="photo image" height="150" src="https://eraspace.com/pub/media/catalog/product/cache/d03018dd3d9615b5c9bd12c6ee948951/i/p/iphone-8-space-grey_4_1_1.jpg" width="150">
# </img></a>
# <div class="product details product-item-details">
# <strong class="product name product-item-name">
# <a class="product-item-link" href="https://eraspace.com/erafone/apple-iphone-8-256gb">
#                                 Apple iPhone 8 256GB                            </a>
# </strong>
# <div class="price-box price-final_price" data-price-box="product-id-937" data-product-id="937" data-role="priceBox">
# <span class="normal-price">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="13499000" data-price-type="finalPrice" id="product-price-937"><span class="price">Rp. 13.499.000</span></span>
# </span>
# </span>
# </div>
# <div class="product-item-inner">
# <div class="product actions product-item-actions">
# <div class="actions-primary">
# <form action="https://eraspace.com/checkout/cart/add/uenc/aHR0cHM6Ly9lcmFzcGFjZS5jb20vZXJhZm9uZS9jYXRhbG9nc2VhcmNoL3Jlc3VsdC8_Y2F0PTQwJnA9MSZxPWlwaG9uZQ%2C%2C/product/937/" data-product-sku="HAP-IP8-256-CON" data-role="tocart-form" method="post">
# <input name="product" type="hidden" value="937"/>
# <input name="uenc" type="hidden" value="aHR0cHM6Ly9lcmFzcGFjZS5jb20vY2hlY2tvdXQvY2FydC9hZGQvdWVuYy9hSFIwY0hNNkx5OWxjbUZ6Y0dGalpTNWpiMjB2WlhKaFptOXVaUzlqWVhSaGJHOW5jMlZoY21Ob0wzSmxjM1ZzZEM4X1kyRjBQVFF3Sm5BOU1TWnhQV2x3YUc5dVpRJTJDJTJDL3Byb2R1Y3QvOTM3Lw,,"/>
# <input name="form_key" type="hidden" value="EC1ihyQcEx6jUzAY"> <input class="addtocart-button-wrapper" data-title="Masukkan Keranjang Belanja " type="hidden"/>
# <button class="action tocart primary" title="Masukkan Keranjang Belanja " type="submit">
# <span>Masukkan Keranjang Belanja </span>
# </button>
# </input></form>
# </div>
# <div class="actions-secondary" data-role="add-to-links">
# <a aria-label=" Favorit " class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/eraspace.com\/wishlist\/index\/add\/","data":{"product":"937","uenc":"aHR0cHM6Ly9lcmFzcGFjZS5jb20vZXJhZm9uZS9jYXRhbG9nc2VhcmNoL3Jlc3VsdC8_Y2F0PTQwJnA9MSZxPWlwaG9uZQ,,"}}' href="#" role="button" title="Favoritkan">
# <span>Favoritkan</span>
# </a>
# <a aria-label=" Bandingkan " class="action tocompare" data-post='{"action":"https:\/\/eraspace.com\/catalog\/product_compare\/add\/","data":{"product":"937","uenc":"aHR0cHM6Ly9lcmFzcGFjZS5jb20vZXJhZm9uZS9jYXRhbG9nc2VhcmNoL3Jlc3VsdC8_Y2F0PTQwJnA9MSZxPWlwaG9uZQ,,"}}' href="#" role="button" title=" Bandingkan ">
# <span> Bandingkan </span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>, <li class="item product product-item"> <div class="product-item-info" data-container="product-grid">
# <!-- product badge -->
# <!--
# /**
#  * Copyright © 2019 PT Kemana Teknologi Solusi. All rights reserved.
#  * http://www.kemana.com
#  */
#
# /**
#  * @category Kemana
#  * @package  Kemana_Catalog
#  * @license  http://opensource.org/licenses/osl-3.0.php  Open Software License (OSL 3.0)
#  *
#  *
#  * @author   Imam Kusuma <ikusuma@kemana.com>
#  */
# -->
# <!-- product badge -->
# <a class="product photo product-item-photo" href="https://eraspace.com/erafone/apple-iphone-xs-max-64gb" tabindex="-1">
# <img alt="Apple iPhone Xs Max 64GB" class="photo image" height="150" src="https://eraspace.com/pub/media/catalog/product/cache/d03018dd3d9615b5c9bd12c6ee948951/i/p/iphone-xs-max-space-gray_1_1_4.jpg" width="150"/>
# </a>
# <div class="product details product-item-details">
# <strong class="product name product-item-name">
# <a class="product-item-link" href="https://eraspace.com/erafone/apple-iphone-xs-max-64gb">
#                                 Apple iPhone Xs Max 64GB                            </a>
# </strong>
# <div class="price-box price-final_price" data-price-box="product-id-950" data-product-id="950" data-role="priceBox">
# <span class="normal-price">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="19999000" data-price-type="finalPrice" id="product-price-950"><span class="price">Rp. 19.999.000</span></span>
# </span>
# </span>
# </div>
# <div class="product-item-inner">
# <div class="product actions product-item-actions">
# <div class="actions-primary">
# <form action="https://eraspace.com/checkout/cart/add/uenc/aHR0cHM6Ly9lcmFzcGFjZS5jb20vZXJhZm9uZS9jYXRhbG9nc2VhcmNoL3Jlc3VsdC8_Y2F0PTQwJnA9MSZxPWlwaG9uZQ%2C%2C/product/950/" data-product-sku="HAP-IPXSM64-CON" data-role="tocart-form" method="post">
# <input name="product" type="hidden" value="950"/>
# <input name="uenc" type="hidden" value="aHR0cHM6Ly9lcmFzcGFjZS5jb20vY2hlY2tvdXQvY2FydC9hZGQvdWVuYy9hSFIwY0hNNkx5OWxjbUZ6Y0dGalpTNWpiMjB2WlhKaFptOXVaUzlqWVhSaGJHOW5jMlZoY21Ob0wzSmxjM1ZzZEM4X1kyRjBQVFF3Sm5BOU1TWnhQV2x3YUc5dVpRJTJDJTJDL3Byb2R1Y3QvOTUwLw,,"/>
# <input name="form_key" type="hidden" value="EC1ihyQcEx6jUzAY"> <input class="addtocart-button-wrapper" data-title="Masukkan Keranjang Belanja " type="hidden"/>
# <button class="action tocart primary" title="Masukkan Keranjang Belanja " type="submit">
# <span>Masukkan Keranjang Belanja </span>
# </button>
# </input></form>
# </div>
# <div class="actions-secondary" data-role="add-to-links">
# <a aria-label=" Favorit " class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/eraspace.com\/wishlist\/index\/add\/","data":{"product":"950","uenc":"aHR0cHM6Ly9lcmFzcGFjZS5jb20vZXJhZm9uZS9jYXRhbG9nc2VhcmNoL3Jlc3VsdC8_Y2F0PTQwJnA9MSZxPWlwaG9uZQ,,"}}' href="#" role="button" title="Favoritkan">
# <span>Favoritkan</span>
# </a>
# <a aria-label=" Bandingkan " class="action tocompare" data-post='{"action":"https:\/\/eraspace.com\/catalog\/product_compare\/add\/","data":{"product":"950","uenc":"aHR0cHM6Ly9lcmFzcGFjZS5jb20vZXJhZm9uZS9jYXRhbG9nc2VhcmNoL3Jlc3VsdC8_Y2F0PTQwJnA9MSZxPWlwaG9uZQ,,"}}' href="#" role="button" title=" Bandingkan ">
# <span> Bandingkan </span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>, <li class="item product product-item"> <div class="product-item-info" data-container="product-grid">
# <!-- product badge -->
# <!--
# /**
#  * Copyright © 2019 PT Kemana Teknologi Solusi. All rights reserved.
#  * http://www.kemana.com
#  */
#
# /**
#  * @category Kemana
#  * @package  Kemana_Catalog
#  * @license  http://opensource.org/licenses/osl-3.0.php  Open Software License (OSL 3.0)
#  *
#  *
#  * @author   Imam Kusuma <ikusuma@kemana.com>
#  */
# -->
# <!-- product badge -->
# <a class="product photo product-item-photo" href="https://eraspace.com/erafone/apple-iphone-xr-128gb" tabindex="-1">
# <img alt="Apple iPhone Xr 128GB" class="photo image" height="150" src="https://eraspace.com/pub/media/catalog/product/cache/d03018dd3d9615b5c9bd12c6ee948951/i/p/iphone-xr-red_1_1_1_1.jpg" width="150"/>
# </a>
# <div class="product details product-item-details">
# <strong class="product name product-item-name">
# <a class="product-item-link" href="https://eraspace.com/erafone/apple-iphone-xr-128gb">
#                                 Apple iPhone Xr 128GB                            </a>
# </strong>
# <div class="price-box price-final_price" data-price-box="product-id-941" data-product-id="941" data-role="priceBox">
# <span class="normal-price">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="13999000" data-price-type="finalPrice" id="product-price-941"><span class="price">Rp. 13.999.000</span></span>
# </span>
# </span>
# </div>
# <div class="product-item-inner">
# <div class="product actions product-item-actions">
# <div class="actions-primary">
# <form action="https://eraspace.com/checkout/cart/add/uenc/aHR0cHM6Ly9lcmFzcGFjZS5jb20vZXJhZm9uZS9jYXRhbG9nc2VhcmNoL3Jlc3VsdC8_Y2F0PTQwJnA9MSZxPWlwaG9uZQ%2C%2C/product/941/" data-product-sku="HAP-IPXR128-CON" data-role="tocart-form" method="post">
# <input name="product" type="hidden" value="941"/>
# <input name="uenc" type="hidden" value="aHR0cHM6Ly9lcmFzcGFjZS5jb20vY2hlY2tvdXQvY2FydC9hZGQvdWVuYy9hSFIwY0hNNkx5OWxjbUZ6Y0dGalpTNWpiMjB2WlhKaFptOXVaUzlqWVhSaGJHOW5jMlZoY21Ob0wzSmxjM1ZzZEM4X1kyRjBQVFF3Sm5BOU1TWnhQV2x3YUc5dVpRJTJDJTJDL3Byb2R1Y3QvOTQxLw,,"/>
# <input name="form_key" type="hidden" value="EC1ihyQcEx6jUzAY"> <input class="addtocart-button-wrapper" data-title="Masukkan Keranjang Belanja " type="hidden"/>
# <button class="action tocart primary" title="Masukkan Keranjang Belanja " type="submit">
# <span>Masukkan Keranjang Belanja </span>
# </button>
# </input></form>
# </div>
# <div class="actions-secondary" data-role="add-to-links">
# <a aria-label=" Favorit " class="action towishlist" data-action="add-to-wishlist" data-post='{"action":"https:\/\/eraspace.com\/wishlist\/index\/add\/","data":{"product":"941","uenc":"aHR0cHM6Ly9lcmFzcGFjZS5jb20vZXJhZm9uZS9jYXRhbG9nc2VhcmNoL3Jlc3VsdC8_Y2F0PTQwJnA9MSZxPWlwaG9uZQ,,"}}' href="#" role="button" title="Favoritkan">
# <span>Favoritkan</span>
# </a>
# <a aria-label=" Bandingkan " class="action tocompare" data-post='{"action":"https:\/\/eraspace.com\/catalog\/product_compare\/add\/","data":{"product":"941","uenc":"aHR0cHM6Ly9lcmFzcGFjZS5jb20vZXJhZm9uZS9jYXRhbG9nc2VhcmNoL3Jlc3VsdC8_Y2F0PTQwJnA9MSZxPWlwaG9uZQ,,"}}' href="#" role="button" title=" Bandingkan ">
# <span> Bandingkan </span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>]

# %% [markdown]
# ## Get the Information

# %%
nama_produk = []
harga_produk = []
for p in produk_hp:
    nama = p.find('a','product-item-link').get_text()
    harga = p.find('span','price').get_text()
    nama_produk.append(nama)
    harga_produk.append(harga)

# %% [markdown]
# ## Organizing the Information

# %%
produk_dict = {
    'nama':nama_produk,
    'harga':harga_produk
}

# %%
df = pd.DataFrame(produk_dict, columns=['nama','harga'])

# %%
df.head()
# Out:
#                                                 nama           harga
# 0  \n                                Apple iPhone...  Rp. 19.599.000
# 1  \n                                Apple iPhone...  Rp. 19.399.000
# 2  \n                                Apple iPhone...  Rp. 26.599.000
# 3  \n                                Apple iPhone...  Rp. 12.999.000
# 4  \n                                Apple iPhone...  Rp. 22.999.000

# %% [markdown]
# ## Data Cleaning

# %%
df['nama'].replace(r'\s\s','', regex=True)
# Out:
# 0           Apple iPhone Xs 64GB
# 1           Apple iPhone X 256GB
# 2          Apple iPhone Xs 512GB
# 3           Apple iPhone Xr 64GB
# 4      Apple iPhone Xs Max 256GB
# 5          Apple iPhone Xs 256GB
# 6          Apple iPhone Xr 256GB
# 7      Apple iPhone Xs Max 512GB
# 8      Apple iPhone 8 Plus 256GB
# 9           Apple iPhone 8 256GB
# 10      Apple iPhone Xs Max 64GB
# 11         Apple iPhone Xr 128GB
# Name: nama, dtype: object

# %%
df['nama'] = df['nama'].replace(r'\s\s','', regex=True)
df.head()
# Out:
#                          nama           harga
# 0        Apple iPhone Xs 64GB  Rp. 19.599.000
# 1        Apple iPhone X 256GB  Rp. 19.399.000
# 2       Apple iPhone Xs 512GB  Rp. 26.599.000
# 3        Apple iPhone Xr 64GB  Rp. 12.999.000
# 4   Apple iPhone Xs Max 256GB  Rp. 22.999.000

# %%
df['harga'].replace(r'[Rp.]','',regex=True)
# Out:
# 0      19599000
# 1      19399000
# 2      26599000
# 3      12999000
# 4      22999000
# 5      22599000
# 6      15999000
# 7      26999000
# 8      15499000
# 9      13499000
# 10     19999000
# 11     13999000
# Name: harga, dtype: object

# %%
df['harga'] = df['harga'].replace(r'[Rp.]','',regex=True)
df.head()
# Out:
#                          nama      harga
# 0        Apple iPhone Xs 64GB   19599000
# 1        Apple iPhone X 256GB   19399000
# 2       Apple iPhone Xs 512GB   26599000
# 3        Apple iPhone Xr 64GB   12999000
# 4   Apple iPhone Xs Max 256GB   22999000

# %%
df
# Out:
#                           nama      harga
# 0         Apple iPhone Xs 64GB   19599000
# 1         Apple iPhone X 256GB   19399000
# 2        Apple iPhone Xs 512GB   26599000
# 3         Apple iPhone Xr 64GB   12999000
# 4    Apple iPhone Xs Max 256GB   22999000
# 5        Apple iPhone Xs 256GB   22599000
# 6        Apple iPhone Xr 256GB   15999000
# 7    Apple iPhone Xs Max 512GB   26999000
# 8    Apple iPhone 8 Plus 256GB   15499000
# 9         Apple iPhone 8 256GB   13499000
# 10    Apple iPhone Xs Max 64GB   19999000
# 11       Apple iPhone Xr 128GB   13999000

# %% [markdown]
# # Case 2 Samsung - Erafone (Multiple Pages)

# %%
p_range = range(1,4)
nama_produk = []
harga_produk = []
for p in p_range:
    url = f'https://eraspace.com/erafone/catalogsearch/result/?cat=40&p={p}&q=samsung'
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    produk = soup.find_all('li', 'item product product-item')
    try:
        for x in produk:
            nama = x.find('a','product-item-link').get_text()
            harga = x.find('span','price').get_text().replace('Rp', '').replace('.','')
            nama_produk.append(nama)
            harga_produk.append(harga)
    except:
        continue
produk_dict = { 'nama':nama_produk, 'harga':harga_produk }
df = pd.DataFrame(produk_dict, columns=['nama','harga'])
df['nama'].replace(r'\s\s','',regex=True, inplace=True)

# %%
df.head()
# Out:
#                                                 nama      harga
# 0               Samsung Galaxy Tab A 10.1 T515N 2019    4799000
# 1                          Samsung Galaxy S10e 128GB   10499000
# 2                        Samsung Galaxy Note10 256GB   13999000
# 3                     Samsung Galaxy A50 (6GB/128GB)    4349000
# 4   Samsung Galaxy Note9 (6GB/128GB) FREE Bluetoo...   12649000

# %% [markdown]
# # Case 3 Jakarta Notebook - Iphone Acc (Multiple Pages)

# %%
p_range = range(1,23)
nama_produk = []
harga_produk = []
links = []
for p in p_range:
    url = f'https://www.jakartanotebook.com/search?key=iphone&page={p}'
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    produk = soup.find_all('div', 'product-list')
    try:
        for x in produk:
            nama = x.find('a','product-list__title').get_text()
            harga = x.find('span','product-list__price').get_text()
            link = x.find('img').get('src')
            nama_produk.append(nama)
            harga_produk.append(harga)
            links.append(link)
    except:
        continue
produk_dict = { 'nama':nama_produk, 'harga':harga_produk, 'link':links }
df = pd.DataFrame(produk_dict, columns=['nama','harga', 'link'])

# %%
df.head()
# Out:
#                                                 nama       harga  \
# 0  Anti Crack TPU Silicone Softcase for iPhone 7 ...  Rp. 10.800
# 1  Sensitive Thermal Hardcase for iPhone 7/8 Plus...  Rp. 12.900
# 2  Anti Crack TPU Silicone Softcase for iPhone X ...   Rp. 8.800
# 3  Anti Crack TPU Silicone Softcase for iPhone 7 ...  Rp. 10.800
# 4  Anti Crack TPU Silicone Softcase for Xiaomi Mi...   Rp. 3.900
#
#                                                 link
# 0  https://www.jakartanotebook.com/images/product...
# 1  https://www.jakartanotebook.com/images/product...
# 2  https://www.jakartanotebook.com/images/product...
# 3  https://www.jakartanotebook.com/images/product...
# 4  https://www.jakartanotebook.com/images/product...

# %% [markdown]
# # Case 4 IndoXX1 - Movie (Single Page)

# %%
url = 'https://indoxx1.kim'
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')
produk = soup.find_all('div', 'ml-item')

# %%
nama_produk = []
durasi = []
ratings = []
for p in produk:
    nama = p.find('div','mli-info').get_text()
    dur = p.find('span','mli-durasi').get_text()
    rating = p.find('span','mli-rating').get_text()
    nama_produk.append(nama)
    durasi.append(dur)
    ratings.append(rating)

# %%
produk_dict = { 'nama':nama_produk, 'durasi':durasi, 'rating':ratings }
df = pd.DataFrame(produk_dict, columns=['nama','durasi', 'rating'])

# %%
df
# Out:
#                                             nama durasi rating
# 0                             Toy Story 4 (2019)     99    8.7
# 1               Spider-Man: Far from Home (2019)    128    8.2
# 2             The Battle: Roar to Victory (2019)    134    6.7
# 3                            Child's Play (2019)     89    6.5
# 4                                    Anna (2019)    119    6.8
# 5                               Yesterday (2019)    116    7.1
# 6                          Paradise Hills (2019)     93    7.5
# 7                         The Divine Fury (2019)    129    6.7
# 8                          It Chapter Two (2019)    160    7.2
# 9                       Avengers: Endgame (2019)    181    8.6
# 10                    X-Men: Dark Phoenix (2019)    113      6
# 11                                Aladdin (2019)    127    7.4
# 12                                   EXIT (2019)    103    7.2
# 13                Inside Man: Most Wanted (2019)    106      -
# 14                               Super 30 (2019)    153    8.5
# 15                 Can You Keep a Secret? (2019)     94      -
# 16      John Wick: Chapter 3 - Parabellum (2019)    131    8.2
# 17                                     It (2017)    134    7.4
# 18             Men in Black International (2019)    114    5.5
# 19                            Friend Zone (2019)    118    7.5
# 20         Godzilla: King of the Monsters (2019)    131    6.7
# 21                       Angel Has Fallen (2019)    111      -
# 22  Fast & Furious Presents: Hobbs & Shaw (2019)    122    7.7
# 23                           Eternal Code (2019)    105    8.6
